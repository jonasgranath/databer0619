# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize 
import matplotlib as plt

# %%
url = 'https://sandbox.iexapis.com/stable/stock/AMZN/chart/1m?token=Tpk_1fbd7058bd0c4e5a9ba085de13455ea0'

# %%
response = requests.get(url)
results = response.json()

# %%
response
# Out:
# <Response [200]>

# %%
commits = json_normalize(results)

# %%
df=pd.DataFrame(results)

# %%
df
# Out:
#     change  changeOverTime  changePercent    close        date     high  \
# 0     0.00        0.000000         0.0000  1897.60  2019-05-20  1868.72
# 1    -1.46       -0.000800        -0.0780  1882.46  2019-05-21  1957.00
# 2     2.27        0.000386         0.1206  1875.83  2019-05-22  1957.51
# 3   -44.30       -0.023993        -2.4112  1896.56  2019-05-23  1930.00
# 4     7.90       -0.019242         0.4323  1898.40  2019-05-24  1894.77
# 5    13.19       -0.012309         0.7553  1918.01  2019-05-28  1935.63
# 6   -17.66       -0.021880        -0.9420  1831.51  2019-05-29  1858.00
# 7    -2.93       -0.023453        -0.1650  1885.95  2019-05-30  1888.57
# 8   -42.12       -0.046825        -2.2914  1795.87  2019-05-31  1829.85
# 9   -83.52       -0.091493        -4.8259  1773.79  2019-06-03  1814.83
# 10   38.19       -0.070050         2.1962  1733.20  2019-06-04  1764.60
# 11    8.98       -0.064826         0.5300  1762.00  2019-06-05  1779.00
# ...

# %%
df=pd.read_csv('/Users/jonas_gratt/desktop/test/EUR_USD Historical Data.csv')

# %%
df = df.set_index('Date')

# %%
df.head()
# Out:
#                Price    Open    High     Low Change %
# Date
# Jul 16, 2018  1.1710  1.1676  1.1726  1.1674    0.21%
# Jul 13, 2018  1.1685  1.1669  1.1688  1.1610    0.11%
# Jul 12, 2018  1.1672  1.1674  1.1697  1.1648   -0.02%
# Jul 11, 2018  1.1674  1.1745  1.1760  1.1665   -0.60%
# Jul 10, 2018  1.1744  1.1751  1.1764  1.1690   -0.06%

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = df.iloc[::-1]

# %%
plt.figure(figsize=(20,10))

# %%
df['Price'].plot(figsize=(20,10), linewidth = 10,)
