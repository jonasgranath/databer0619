# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = 'https://api.coingecko.com/api/v3/coins/bitcoin/market_chart?vs_currency=usd&days=30'

# %%
response = requests.get(url)
j = response.json()
response
# Out:
# <Response [200]>

# %%
df =pd.DataFrame(j['prices'], columns=['time', 'price'])
df['time'] = pd.to_datetime(df['time'], unit= 'ms')

# %%
df.set_index('time', inplace=True)

# %%
df = df.groupby(pd.Grouper(freq="d")).mean()
df.head()
# Out:
#                   price
# time
# 2019-05-19  7964.512590
# 2019-05-20  7899.671829
# 2019-05-21  7928.995803
# 2019-05-22  7888.087650
# 2019-05-23  7699.755654

# %%
bdf.plot()

# %%
url_dodge = 'https://api.coingecko.com/api/v3/coins/dogecoin/market_chart?vs_currency=usd&days=30'

# %%
response2 = requests.get(url_dodge)
j2 = response2.json()

df2 =pd.DataFrame(j2['prices'], columns=['time', 'price'])
df2['time'] = pd.to_datetime(df2['time'], unit= 'ms')

df2.set_index('time', inplace=True)
df2 = df2.groupby(pd.Grouper(freq="d")).mean()
df2.head()
# Out:
#                price
# time
# 2019-05-19  0.003144
# 2019-05-20  0.003032
# 2019-05-21  0.003018
# 2019-05-22  0.003000
# 2019-05-23  0.002907

# %%
plt = df2.plot()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x11a99fe80>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11a1f7fd0>)
